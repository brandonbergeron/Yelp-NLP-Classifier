# %% [markdown]
# # Project 5: Group Project
# #### Author: Adam Pardo, Brandon Bergeron, Eric Bayless, Ramesh Babu

# %% [markdown]
# ### 01 - Data Collection and Data Cleaning

# %% [markdown]
# Task:

# %% [markdown]
# ### ***Before running this notebook, data files should be downloaded from [Kaggle](https://www.kaggle.com/yelp-dataset/yelp-dataset) and placed in the data folder

# %%
# import libraries here 
import pandas as pd
import os

# %% [markdown]
# ## Businesses

# %%
# import Business.json
business_json_path = '../data/yelp_academic_dataset_business.json'
df_business = pd.read_json(business_json_path, lines=True)

# %%
# function to pull businesses by city, with option to sample

def city_restaurants(df, city_name, samples=None):
    """
     Takes in the dataframe of yelp businesses, and returns only the restaurants from a given city.
    
    ARGS:
    
        df: dataframe of businesses
        city_name (string): Name of city to pull restaurants from
        samples (int): number of restaurants to sample from df (defalt=None)
        
    """
    #--load restaurants in city_name
    df_city = df[df['city'] == city_name]
    df_city = df_city.dropna(subset=['categories'])
    
    #--keep restaurants with reviews between 100-300
    restaurants = df_city[df_city['categories'].str.contains('Restaurant')]
    restaurants_reduced = restaurants[(restaurants['review_count'] > 100) & (restaurants['review_count'] < 300)]
    restaurants_reduced.reset_index(drop=True, inplace=True)
    
    #--returns all restaurants if no samples
    if samples == None:
        restaurants_reduced.to_csv(f'../data/{city_name.replace(" ", "_")}_restaurants_large.csv', index = False)
        return restaurants_reduced
    
    else:
        #creation of sample restaurants
        restaurant_samples = pd.concat([restaurants_reduced[restaurants_reduced['is_open'] == 1].sample(samples//2), restaurants_reduced[restaurants_reduced['is_open'] == 0].sample(samples//2)])
        restaurant_samples.reset_index(drop=True, inplace=True)
    
        restaurant_samples.to_csv(f'./data/{city_name.replace(" ", "_")}_{samples}.csv', index = False)
        return restaurant_samples

# %%
#--Creation of initial sample size 
#city_restaurants(df_business, 'Las Vegas', 400)

# %%
city_restaurants(df_business, 'Las Vegas')
# Out:
#                  business_id                      name  \
# 0     Yr_w9lakJrKMyEG_hI6zbA   Fat Moe's Pizza & Wings
# 1     AN0bWhisCf6LN9eHZ7DQ3w     Los Olivos Ristorante
# 2     oUX2bYbqjqST-urKbOHG6w               Loftti Cafe
# 3     FiW6w5nmhlUoJAyNofb4jg          Fruits and Roots
# 4     q3YnYPjLuBGRDi_59yTC5g  Sidestreet Pho and Grill
# ...                      ...                       ...
# 2432  VkECNTcZZ1mdN-VJltJcWA                  King & I
# 2433  P3xSYeiJFkbdBwpnEncPTg         Aroy Thai Kitchen
# 2434  ak-f8IV0ZdDeI4oYnjA1Pw      Habaneros Taco Grill
# 2435  PIXl4WvAqjl2w9Lj81zXvQ       Zest - Bistro & Bar
# 2436  5VXlHFrYZZzj7zfZEsz5nQ         Dragon Noodle Co.
#
#                                      address       city state postal_code  \
# 0                6125 W Tropicana Ave, Ste F  Las Vegas    NV       89103
# 1                       3759 E Desert Inn Rd  Las Vegas    NV       89121
# 2                7729 S Rainbow Blvd, Ste 9B  Las Vegas    NV       89139
# 3                       5020 Blue Diamond Rd  Las Vegas    NV       89139
# 4               8560 W Desert Inn Rd, Ste D1  Las Vegas    NV       89117
# ...                                      ...        ...   ...         ...
# 2432                    1107 E Tropicana Ave  Las Vegas    NV       89119
# 2433            4555 S Ft Apache Rd, Ste 112  Las Vegas    NV       89147
# 2434                   4225 S Fort Apache Rd  Las Vegas    NV       89147
# 2435  10670 Southern Highlands Pkwy, Ste 102  Las Vegas    NV       89141
# 2436                   3770 Las Vegas Blvd S  Las Vegas    NV       89109
#
#        latitude   longitude  stars  review_count  is_open  \
# 0     36.099361 -115.226636    4.0           141        1
# 1     36.129178 -115.092483    5.0           222        1
# 2     36.047942 -115.244167    4.5           284        1
# 3     36.032122 -115.210267    4.5           106        1
# 4     36.130041 -115.277785    4.0           707        1
# ...         ...         ...    ...           ...      ...
# 2432  36.100079 -115.139002    3.5           198        0
# 2433  36.106477 -115.298066    4.5           182        1
# 2434  36.112881 -115.297498    4.0           286        1
# 2435  35.995151 -115.206840    4.5           744        1
# 2436  36.105289 -115.174037    3.0           279        0
#
#                                              attributes  \
# 0     {'RestaurantsAttire': 'u'casual'', 'Restaurant...
# 1     {'WiFi': 'u'free'', 'RestaurantsPriceRange2': ...
# 2     {'OutdoorSeating': 'True', 'BusinessParking': ...
# 3     {'BusinessAcceptsCreditCards': 'True', 'DogsAl...
# 4     {'RestaurantsGoodForGroups': 'True', 'Restaura...
# ...                                                 ...
# 2432  {'RestaurantsTakeOut': 'True', 'BusinessParkin...
# 2433  {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 2434  {'WheelchairAccessible': 'True', 'RestaurantsG...
# 2435  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...
# 2436  {'RestaurantsTakeOut': 'True', 'BusinessAccept...
#
#                                              categories  \
# 0                    Pizza, Salad, Burgers, Restaurants
# 1                                  Restaurants, Italian
# 2     Sandwiches, Shaved Ice, Coffee & Tea, Desserts...
# 3     Coffee & Tea, Food Stands, Food, Restaurants, ...
# 4       Vietnamese, Restaurants, American (Traditional)
# ...                                                 ...
# 2432                     Soup, Salad, Thai, Restaurants
# 2433                                  Restaurants, Thai
# 2434             Mexican, Fast Food, Restaurants, Tacos
# 2435  American (New), Karaoke, Restaurants, Lounges,...
# 2436                               Chinese, Restaurants
#
#                                                   hours
# 0     {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 1     {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...
# 2     {'Monday': '0:0-0:0', 'Tuesday': '8:0-3:0', 'W...
# 3                                 {'Monday': '0:0-0:0'}
# 4     {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
# ...                                                 ...
# 2432  {'Tuesday': '11:0-22:0', 'Wednesday': '11:0-22...
# 2433  {'Monday': '0:0-0:0', 'Tuesday': '10:30-21:30'...
# 2434  {'Monday': '7:0-2:0', 'Tuesday': '7:0-2:0', 'W...
# 2435  {'Monday': '16:0-22:0', 'Tuesday': '16:0-22:0'...
# 2436  {'Monday': '11:0-22:30', 'Tuesday': '11:0-22:3...
#
# [2437 rows x 14 columns]

# %% [markdown]
# ## Reviews

# %%
# creates JsonReader object for iteration over total Reviews

review_json_path = '../data/yelp_academic_dataset_review.json'
size = 500_000

review_reader = pd.read_json(review_json_path, lines=True,
                      dtype={'review_id':str,'user_id':str,
                             'business_id':str,'stars':int,
                             'date':str,'text':str,'useful':int,
                             'funny':int,'cool':int},
                      chunksize=size)

# %%
#---Matches restaurant reviews with df of businesses

def business_reviews(reviews, business_filepath, output_filepath):
    """
    Iterates over the total reviews and extracts reviews that match the businesses given
    
    ARGS:
    
        reviews: JsonReader for iterating over total reviews
        business_filepath (string.csv): .csv filepath with desired businesses
        output_filepath (string.csv): .csv filename for reviews to be saved in  
    
    """
    
    #--reads in .csv file of desired businesses
    df_business = pd.read_csv(business_filepath)
    
    #--stores matches on business_id
    chunk_list = []
    
    #--iterates over JsonReader chunks and matches reviews on business_id's
    for chunk_review in reviews:
        chunk_review = chunk_review.drop(['review_id','useful','funny','cool'], axis=1)
        #--renames duplicate column
        chunk_review = chunk_review.rename(columns={'stars': 'review_stars'})
        chunk_merged = pd.merge(df_business, chunk_review, on='business_id', how='left')
        print(f"{chunk_merged.shape[0]} out of {size:,} related reviews")
        chunk_list.append(chunk_merged)
    
    #--combining all saved reviews, dropping missing reviews, and resetting index for output
    df_reviews = pd.concat(chunk_list, ignore_index=True, join='outer', axis=0)
    df_reviews.dropna(subset=['text'], inplace=True)
    df_reviews.reset_index(drop=True, inplace=True)
    
    #--write df to output_filepath, and return df of reviews for inspection
    df_reviews.to_csv(f'{output_filepath}', index = False)
    return df_reviews

# https://towardsdatascience.com/converting-yelp-dataset-to-csv-using-pandas-2a4c8f03bd88

# %%
# pulling reviews for 400 sample restaurants.
#business_reviews(review_reader, './data/Las_Vegas_400.csv', 'Las_Vegas_400_reviews.csv')

business_reviews(review_reader, '../data/Las_Vegas_restaurants.csv', '../data/Las_Vegas_reviews.csv')
# Out:
# 55979 out of 500,000 related reviews
# 52302 out of 500,000 related reviews
# 50978 out of 500,000 related reviews
# 50267 out of 500,000 related reviews
# 48704 out of 500,000 related reviews
# 54950 out of 500,000 related reviews
# 48589 out of 500,000 related reviews
# 48244 out of 500,000 related reviews
# 50361 out of 500,000 related reviews
# 47188 out of 500,000 related reviews
# 51125 out of 500,000 related reviews
# 54731 out of 500,000 related reviews
# 51511 out of 500,000 related reviews
# 55995 out of 500,000 related reviews
# 53654 out of 500,000 related reviews
# 54913 out of 500,000 related reviews
# 4006 out of 500,000 related reviews
#                    business_id                     name  \
# 0       Yr_w9lakJrKMyEG_hI6zbA  Fat Moe's Pizza & Wings
# 1       Yr_w9lakJrKMyEG_hI6zbA  Fat Moe's Pizza & Wings
# 2       Yr_w9lakJrKMyEG_hI6zbA  Fat Moe's Pizza & Wings
# 3       Yr_w9lakJrKMyEG_hI6zbA  Fat Moe's Pizza & Wings
# 4       Yr_w9lakJrKMyEG_hI6zbA  Fat Moe's Pizza & Wings
# ...                        ...                      ...
# 798257  PIXl4WvAqjl2w9Lj81zXvQ      Zest - Bistro & Bar
# 798258  PIXl4WvAqjl2w9Lj81zXvQ      Zest - Bistro & Bar
# 798259  5VXlHFrYZZzj7zfZEsz5nQ        Dragon Noodle Co.
# 798260  5VXlHFrYZZzj7zfZEsz5nQ        Dragon Noodle Co.
# 798261  5VXlHFrYZZzj7zfZEsz5nQ        Dragon Noodle Co.
#
#                                        address       city state  postal_code  \
# 0                  6125 W Tropicana Ave, Ste F  Las Vegas    NV        89103
# 1                  6125 W Tropicana Ave, Ste F  Las Vegas    NV        89103
# 2                  6125 W Tropicana Ave, Ste F  Las Vegas    NV        89103
# 3                  6125 W Tropicana Ave, Ste F  Las Vegas    NV        89103
# 4                  6125 W Tropicana Ave, Ste F  Las Vegas    NV        89103
# ...                                        ...        ...   ...          ...
# 798257  10670 Southern Highlands Pkwy, Ste 102  Las Vegas    NV        89141
# 798258  10670 Southern Highlands Pkwy, Ste 102  Las Vegas    NV        89141
# 798259                   3770 Las Vegas Blvd S  Las Vegas    NV        89109
# 798260                   3770 Las Vegas Blvd S  Las Vegas    NV        89109
# 798261                   3770 Las Vegas Blvd S  Las Vegas    NV        89109
#
#          latitude   longitude  stars  review_count  is_open  \
# 0       36.099361 -115.226636    4.0           141        1
# 1       36.099361 -115.226636    4.0           141        1
# 2       36.099361 -115.226636    4.0           141        1
# 3       36.099361 -115.226636    4.0           141        1
# 4       36.099361 -115.226636    4.0           141        1
# ...           ...         ...    ...           ...      ...
# 798257  35.995151 -115.206840    4.5           744        1
# 798258  35.995151 -115.206840    4.5           744        1
# 798259  36.105289 -115.174037    3.0           279        0
# 798260  36.105289 -115.174037    3.0           279        0
# 798261  36.105289 -115.174037    3.0           279        0
#
#                                                attributes  \
# 0       {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 1       {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 2       {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 3       {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 4       {'RestaurantsAttire': "u'casual'", 'Restaurant...
# ...                                                   ...
# 798257  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...
# 798258  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...
# 798259  {'RestaurantsTakeOut': 'True', 'BusinessAccept...
# 798260  {'RestaurantsTakeOut': 'True', 'BusinessAccept...
# 798261  {'RestaurantsTakeOut': 'True', 'BusinessAccept...
#
#                                                categories  \
# 0                      Pizza, Salad, Burgers, Restaurants
# 1                      Pizza, Salad, Burgers, Restaurants
# 2                      Pizza, Salad, Burgers, Restaurants
# 3                      Pizza, Salad, Burgers, Restaurants
# 4                      Pizza, Salad, Burgers, Restaurants
# ...                                                   ...
# 798257  American (New), Karaoke, Restaurants, Lounges,...
# 798258  American (New), Karaoke, Restaurants, Lounges,...
# 798259                               Chinese, Restaurants
# 798260                               Chinese, Restaurants
# 798261                               Chinese, Restaurants
#
#                                                     hours  \
# 0       {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 1       {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 2       {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 3       {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 4       {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# ...                                                   ...
# 798257  {'Monday': '16:0-22:0', 'Tuesday': '16:0-22:0'...
# 798258  {'Monday': '16:0-22:0', 'Tuesday': '16:0-22:0'...
# 798259  {'Monday': '11:0-22:30', 'Tuesday': '11:0-22:3...
# 798260  {'Monday': '11:0-22:30', 'Tuesday': '11:0-22:3...
# 798261  {'Monday': '11:0-22:30', 'Tuesday': '11:0-22:3...
#
#                        user_id  review_stars  \
# 0       flaLsGwkBgWb_o_UVhXbTA           5.0
# 1       yXhy8F43qDmSHuY9ubadtw           5.0
# 2       Unhr6Ut9xQowzzohevNdxg           4.0
# 3       LgkNGmjMijSiBlaWCfWtZw           5.0
# 4       FXB9CtInMisA1cET-Mhg5Q           5.0
# ...                        ...           ...
# 798257  J9okZJ4ItAnHR9XJAsHGOQ           5.0
# 798258  EKo8XUd9hhJKk7jBsCbZQg           5.0
# 798259  Zvvt6w1CPzSzGvXXp_LPaA           3.0
# 798260  nTN0IuRJIsfPZKVk-Vl99Q           3.0
# 798261  FaXc882AdZfNVczNu_w-Sg           4.0
#
#                                                      text                 date
# 0       Love their food and their prices. The owners a...  2017-03-03 21:46:36
# 1       This place has definitely improved since the n...  2015-03-05 15:01:11
# 2       Ordered from here just awhile ago as I was cra...  2015-08-07 23:34:12
# 3       Really yummy food that is made on the spot and...  2017-09-10 20:57:11
# 4       We got here by accident since we were looking ...  2017-05-14 04:06:27
# ...                                                   ...                  ...
# 798257  Really nice neighborhood spot. The food is rea...  2019-10-28 02:05:03
# 798258  Out visiting family and stopped at this family...  2019-12-03 04:57:13
# 798259  I love noodles and saw this restaurant while w...  2016-04-15 19:30:14
# 798260  One thing I noticed while walking in/out of th...  2014-04-21 21:07:24
# 798261  I've only had the sushi... but it was great! W...  2015-05-02 09:37:56
#
# [798262 rows x 18 columns]

# %% [markdown]
# ## Confirming Matches

# %%
def business_id_matcher(business_filepath, review_filepath):
    """
    Checks if reviews were correctly collected for desired businesses
    
    ARGS:
    
        business_filepath (str.csv): filepath of businesses
        review_filepath (str.csv): filepath of reviews
    
    """
    return pd.read_csv(business_filepath)['business_id'].value_counts().sum() == len(pd.read_csv(review_filepath)['business_id'].unique())

# %%
business_id_matcher('../data/Las_Vegas_400.csv', '../data/Las_Vegas_400_reviews.csv')
# Out:
# True
